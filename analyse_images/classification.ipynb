# %%
import pandas as pnd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
import keras

tf.config.set_visible_devices([], 'GPU')

#Définition de la longueur et de la largeur de l'image
LONGUEUR_IMAGE = 28
LARGEUR_IMAGE = 28

#Chargement des images
observations_entrainement = pnd.read_csv('datas/fashion-mnist_train.csv')
# Out:
# 2025-11-14 20:23:52.420110: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-14 20:23:53.170409: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-14 20:23:55.473130: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
#On exclut la première colonne (les labels) pour constituer un tableau de pixels
X = np.array(observations_entrainement.iloc[:, 1:])

premiereImage = X[0]
premiereImage = premiereImage.reshape([LONGUEUR_IMAGE,LARGEUR_IMAGE])
plt.imshow(premiereImage)
plt.show()

# %%
y = keras.utils.to_categorical(np.array(observations_entrainement.iloc[:,0]))
X_apprentissage, X_validation, y_apprentissage, y_validation = train_test_split(X, y, test_size=0.2, random_state=13)

# %%
X_apprentissage = X_apprentissage.reshape(X_apprentissage.shape[0], 
                                          LARGEUR_IMAGE, 
                                          LONGUEUR_IMAGE, 1)
X_apprentissage = X_apprentissage.astype('float32')
X_apprentissage /= 255

X_validation = X_validation.reshape(X_validation.shape[0], 
                                    LARGEUR_IMAGE, 
                                    LONGUEUR_IMAGE, 1)
X_validation = X_validation.astype('float32')
X_validation /= 255

# %%
observations_test = pnd.read_csv('datas/fashion-mnist_test.csv')
X_test = np.array(observations_test.iloc[:, 1:])
y_test = tf.keras.utils.to_categorical(np.array(observations_test.iloc[:, 0]))
X_test = X_test.reshape(X_test.shape[0], 
                        LARGEUR_IMAGE, 
                        LONGUEUR_IMAGE, 1)
X_test = X_test.astype('float32')
X_test /= 255

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Input
from keras.layers import Conv2D, MaxPooling2D

# On spécifie les dimensions de l'image d'entrée
dimentionImage = (LARGEUR_IMAGE, LONGUEUR_IMAGE, 1)

# On crée le réseau de neurones couche par couche
reseauNeurone1Convolution = Sequential()

# Ajout de la couche d'entrée
reseauNeurone1Convolution.add(Input(shape=dimentionImage))

#1- Ajout de la couche de convolution comportant
# 32 filtres de de taille 3x3 (Kernel) parcourant l'image
# Une fonction d'activation de type ReLU (Rectified Linear Activation)
# Une image d'entrée de 28px * 28 px 
reseauNeurone1Convolution.add(Conv2D(32, 
                                     kernel_size=(3, 3), 
                                     activation='relu'))

#2- Définition de la fonction de pooling avec une fenêtre de 2px sur 2 px
reseauNeurone1Convolution.add(MaxPooling2D(pool_size=(2, 2)))

#3- Ajout d'une fonction d'ignorance
reseauNeurone1Convolution.add(Dropout(0.2))

#5 - On transforme en une seule ligne
reseauNeurone1Convolution.add(Flatten())

#6 - Ajout d'un réseau de neurones composé de 128 neurones avec 
# une fonction d'activation de type ReLU
reseauNeurone1Convolution.add(Dense(128, activation='relu'))

#7 - Ajout d'un réseau de neurones composé de 10 neurones avec une 
# fonction d'activation de type softmax
reseauNeurone1Convolution.add(Dense(10, activation='softmax'))

# %%
reseauNeurone1Convolution.compile(loss=keras.losses.categorical_crossentropy, 
                                  optimizer=tf.keras.optimizers.Adam(), 
                                  metrics=['accuracy'])

# %%
historique_apprentissage = reseauNeurone1Convolution.fit(
    X_apprentissage, 
    y_apprentissage,
    batch_size=256,
    epochs=10,
    verbose=1,
    validation_data=(X_validation, y_validation))
# Out:
# Epoch 1/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.8085 - loss: 0.5433 - val_accuracy: 0.8645 - val_loss: 0.3855
# Epoch 2/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.8746 - loss: 0.3565 - val_accuracy: 0.8815 - val_loss: 0.3355
# Epoch 3/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.8921 - loss: 0.3111 - val_accuracy: 0.8936 - val_loss: 0.3027
# Epoch 4/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8992 - loss: 0.2837 - val_accuracy: 0.8969 - val_loss: 0.2896
# Epoch 5/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.9059 - loss: 0.2627 - val_accuracy: 0.8987 - val_loss: 0.2817
# Epoch 6/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.9124 - loss: 0.2468 - val_accuracy: 0.8966 - val_loss: 0.2864
# Epoch 7/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.9151 - loss: 0.2338 - val_accuracy: 0.9039 - val_loss: 0.2693
# Epoch 8/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.9212 - loss: 0.2196 - val_accuracy: 0.9111 - val_loss: 0.2529
# Epoch 9/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 0.9267 - loss: 0.2042 - val_accuracy: 0.9090 - val_loss: 0.2503
# Epoch 10/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.9310 - loss: 0.1923 - val_accuracy: 0.9116 - val_loss: 0.2480

# %%
evaluation = reseauNeurone1Convolution.evaluate(X_test, y_test, verbose=0)
print('Erreur:', evaluation[0])
print('Précision:', evaluation[1])
# Out:
# Erreur: 0.2363199144601822
# Précision: 0.9157999753952026

# %%
plt.plot(historique_apprentissage.history['accuracy'])
plt.plot(historique_apprentissage.history['val_accuracy'])
plt.title('Précision du modèle')
plt.ylabel('Précision')
plt.xlabel('Epoch')
plt.legend(['Apprentissage', 'Test'], loc='upper left')
plt.show()

plt.plot(historique_apprentissage.history['loss'])
plt.plot(historique_apprentissage.history['val_loss'])
plt.title('Erreur')
plt.ylabel('Erreur')
plt.xlabel('Epoch')
plt.legend(['Apprentissage', 'Test'], loc='upper left')
plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

generateur_images = tf.keras.preprocessing.image.ImageDataGenerator(
    rotation_range=8,
    width_shift_range=0.08,
    shear_range=0.3,
    height_shift_range=0.08,
    zoom_range=0.08)

# %%
nouvelles_images_apprentissage = generateur_images.flow(
    X_apprentissage, 
    y_apprentissage,
    batch_size=256)

nouvelles_images_validation = generateur_images.flow(
    X_validation, 
    y_validation,
    batch_size=256)

historique_apprentissage = reseauNeurone1Convolution.fit(
    nouvelles_images_apprentissage,
    steps_per_epoch=48000//256,
    epochs=50,
    validation_data=nouvelles_images_validation,
    validation_steps=12000//256,
    verbose=1 )

evaluation = reseauNeurone1Convolution.evaluate(X_test, y_test, verbose=0)

print('Erreur :', evaluation[0])
print('Précision:', evaluation[1])
# Out:
# Epoch 1/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - accuracy: 0.8280 - loss: 0.4583 - val_accuracy: 0.8462 - val_loss: 0.4136
# Epoch 2/50
#   1/187 ━━━━━━━━━━━━━━━━━━━━ 9s 50ms/step - accuracy: 0.8555 - loss: 0.3865
# /home/vscode/.local/lib/python3.12/site-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8555 - loss: 0.3865 - val_accuracy: 0.8476 - val_loss: 0.4131
# Epoch 3/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 21s 107ms/step - accuracy: 0.8503 - loss: 0.4052 - val_accuracy: 0.8603 - val_loss: 0.3840
# Epoch 4/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8594 - loss: 0.3574 - val_accuracy: 0.8602 - val_loss: 0.3801
# Epoch 5/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 41s 112ms/step - accuracy: 0.8599 - loss: 0.3799 - val_accuracy: 0.8686 - val_loss: 0.3638
# Epoch 6/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8359 - loss: 0.3784 - val_accuracy: 0.8633 - val_loss: 0.3721
# Epoch 7/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - accuracy: 0.8627 - loss: 0.3679 - val_accuracy: 0.8705 - val_loss: 0.3550
# Epoch 8/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8867 - loss: 0.3466 - val_accuracy: 0.8663 - val_loss: 0.3572
# Epoch 9/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.8676 - loss: 0.3538 - val_accuracy: 0.8730 - val_loss: 0.3400
# Epoch 10/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8359 - loss: 0.3965 - val_accuracy: 0.8753 - val_loss: 0.3392
# Epoch 11/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.8708 - loss: 0.3477 - val_accuracy: 0.8731 - val_loss: 0.3432
# Epoch 12/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8711 - loss: 0.2987 - val_accuracy: 0.8730 - val_loss: 0.3411
# Epoch 13/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - accuracy: 0.8748 - loss: 0.3377 - val_accuracy: 0.8775 - val_loss: 0.3370
# Epoch 14/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9023 - loss: 0.3005 - val_accuracy: 0.8784 - val_loss: 0.3309
# Epoch 15/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - accuracy: 0.8757 - loss: 0.3348 - val_accuracy: 0.8775 - val_loss: 0.3362
# Epoch 16/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9062 - loss: 0.2639 - val_accuracy: 0.8752 - val_loss: 0.3339
# Epoch 17/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.8785 - loss: 0.3280 - val_accuracy: 0.8792 - val_loss: 0.3294
# Epoch 18/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8594 - loss: 0.3311 - val_accuracy: 0.8778 - val_loss: 0.3268
# Epoch 19/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.8798 - loss: 0.3216 - val_accuracy: 0.8769 - val_loss: 0.3274
# Epoch 20/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9023 - loss: 0.2926 - val_accuracy: 0.8807 - val_loss: 0.3259
# Epoch 21/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.8821 - loss: 0.3161 - val_accuracy: 0.8859 - val_loss: 0.3135
# Epoch 22/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8945 - loss: 0.3118 - val_accuracy: 0.8841 - val_loss: 0.3147
# Epoch 23/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - accuracy: 0.8843 - loss: 0.3116 - val_accuracy: 0.8830 - val_loss: 0.3106
# Epoch 24/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9023 - loss: 0.2683 - val_accuracy: 0.8827 - val_loss: 0.3124
# Epoch 25/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 17s 43ms/step - accuracy: 0.8842 - loss: 0.3112 - val_accuracy: 0.8864 - val_loss: 0.3052
# Epoch 26/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8984 - loss: 0.3081 - val_accuracy: 0.8893 - val_loss: 0.3027
# Epoch 27/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.8862 - loss: 0.3058 - val_accuracy: 0.8881 - val_loss: 0.3037
# Epoch 28/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8672 - loss: 0.3469 - val_accuracy: 0.8837 - val_loss: 0.3079
# Epoch 29/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.8893 - loss: 0.2990 - val_accuracy: 0.8919 - val_loss: 0.2959
# Epoch 30/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8867 - loss: 0.3334 - val_accuracy: 0.8888 - val_loss: 0.2999
# Epoch 31/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - accuracy: 0.8882 - loss: 0.2994 - val_accuracy: 0.8950 - val_loss: 0.2903
# Epoch 32/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8789 - loss: 0.3268 - val_accuracy: 0.8895 - val_loss: 0.3037
# Epoch 33/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - accuracy: 0.8901 - loss: 0.2972 - val_accuracy: 0.8918 - val_loss: 0.3009
# Epoch 34/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8633 - loss: 0.3176 - val_accuracy: 0.8894 - val_loss: 0.3000
# Epoch 35/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.8919 - loss: 0.2919 - val_accuracy: 0.8858 - val_loss: 0.2974
# Epoch 36/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8984 - loss: 0.2450 - val_accuracy: 0.8922 - val_loss: 0.2972
# Epoch 37/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 22s 61ms/step - accuracy: 0.8925 - loss: 0.2893 - val_accuracy: 0.8849 - val_loss: 0.3104
# Epoch 38/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8945 - loss: 0.2655 - val_accuracy: 0.8888 - val_loss: 0.3004
# Epoch 39/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - accuracy: 0.8913 - loss: 0.2883 - val_accuracy: 0.8914 - val_loss: 0.2977
# Epoch 40/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8594 - loss: 0.3891 - val_accuracy: 0.8953 - val_loss: 0.2909
# Epoch 41/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - accuracy: 0.8932 - loss: 0.2868 - val_accuracy: 0.8916 - val_loss: 0.2930
# Epoch 42/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8945 - loss: 0.2794 - val_accuracy: 0.8945 - val_loss: 0.2905
# Epoch 43/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 10s 54ms/step - accuracy: 0.8942 - loss: 0.2853 - val_accuracy: 0.8855 - val_loss: 0.3058
# Epoch 44/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8945 - loss: 0.2861 - val_accuracy: 0.8861 - val_loss: 0.3058
# Epoch 45/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 17s 43ms/step - accuracy: 0.8959 - loss: 0.2796 - val_accuracy: 0.8916 - val_loss: 0.2885
# Epoch 46/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9062 - loss: 0.2454 - val_accuracy: 0.8881 - val_loss: 0.3002
# Epoch 47/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - accuracy: 0.8946 - loss: 0.2815 - val_accuracy: 0.8932 - val_loss: 0.2935
# Epoch 48/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8984 - loss: 0.2828 - val_accuracy: 0.8937 - val_loss: 0.2914
# Epoch 49/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 10s 48ms/step - accuracy: 0.8975 - loss: 0.2767 - val_accuracy: 0.8966 - val_loss: 0.2816
# Epoch 50/50
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8789 - loss: 0.3199 - val_accuracy: 0.8949 - val_loss: 0.2850
# Erreur : 0.22419658303260803
# Précision: 0.9229000210762024

# %%
model_json = reseauNeurone1Convolution.to_json() 
with open("modele/modele.json", "w") as json_file:
    json_file.write(model_json)

reseauNeurone1Convolution.save_weights("modele/modele.weights.h5")
print("Modèle sauvegardé !")
# Out:
# Modèle sauvegardé !
